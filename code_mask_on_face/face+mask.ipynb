# %% [markdown]
# # Мора во colab со овој код заради потребата на face_recognition од јак GPU.

# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 41kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=ae60d1e7afd0a77389a863158c072dcb770951c75b759c48cd36b30401ce951c
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from zipfile import ZipFile
zf = ZipFile('drive/My Drive/data_masks_2/data_masks.zip', 'r')  # stavete vasa pateka tuka do zip fajlot (ke mora da se prvo vo zip na drive)
zf.extractall('data_masks')
zf.close()

# %%
import cv2
import os
from mask import create_mask

folder_path = "data_masks/data_masks/train/without_mask" #ova e pateka do folderot (veke odzipuvaniot na colab) so slikite

#c = 0
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
for i in range(len(images)):
    print("the path of the image is", images[i])
    #image = cv2.imread(images[i])
    #c = c + 1
    create_mask(images[i])
# Out:
# the path of the image is data_masks/data_masks/train/without_mask/154.jpg
# Save to data_masks/data_masks/train/without_mask/154-with-mask.jpg
# the path of the image is data_masks/data_masks/train/without_mask/182.jfif
# Save to data_masks/data_masks/train/without_mask/182-with-mask.jfif
# the path of the image is data_masks/data_masks/train/without_mask/126.jpg
# Save to data_masks/data_masks/train/without_mask/126-with-mask.jpg
# the path of the image is data_masks/data_masks/train/without_mask/images (16).jfif
# Save to data_masks/data_masks/train/without_mask/images (16)-with-mask.jfif
# the path of the image is data_masks/data_masks/train/without_mask/images - 2020-07-15T084705.907.jfif
# Save to data_masks/data_masks/train/without_mask/images - 2020-07-15T084705.907-with-mask.jfif
# the path of the image is data_masks/data_masks/train/without_mask/168.jpg
# Save to data_masks/data_masks/train/without_mask/168-with-mask.jpg
# ...

# %% [markdown]
# ## Save from colab to drive (enter specific location of the files in colab to copy to specific folder/folder2 to drive)
#
# ### The images with (-with-mask-) in the name are the generated images.

# %%
cp /content/data_masks/data_masks/train/without_mask/* /content/drive/My\ Drive/check/check2 #stavete pateka do google drive fajl

# %% [markdown]
# ### Со ова ќе ја спуштите секоја генерирана слика со маска посебно (многу е важна патеката каде се)

# %%
from google.colab import files

# %%
folder_path = "data_masks/data_masks/train/without_mask" #ova e pateka do folderot (veke odzipuvaniot na colab) so slikite

images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
for i in range(len(images)):
    if "-with-mask" in images[i]:
      print(i)
      files.download(images[i])
